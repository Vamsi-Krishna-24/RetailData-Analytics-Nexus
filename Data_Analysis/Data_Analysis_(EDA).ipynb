# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
## All the required libraries are read

# %%
## The CSV file is read by pandas, named as data.
data = pd.read_csv("/Users/surisettivamsikrishna/Downloads/OnlineRetail.csv",encoding='latin-1')
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#Basic Info 
data.info()

# Summary statistics
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# ...

# %%
# Checking all the null values 
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Handling the missing values.
data['Description'].fillna('No_description',inplace=True)
data['CustomerID'].fillna('0',inplace=True)
# Out:
# /var/folders/10/4p6gdwfx3g74kjfj2_xqxz140000gn/T/ipykernel_25650/2275725485.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data['CustomerID'].fillna('0',inplace=True)

# %%
# All the null values has been filled.
data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
data['Quantity'].hist(bins=20,color='skyblue',edgecolor='black')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.title('Distribution of Quantity')
plt.show()

# %%
# HeatMap
corr_matrix = data[['Quantity', 'UnitPrice', 'CustomerID']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom

# %%
# Creating new data to check which customer buys huge quantities in a year
data2 = data

# %%
data2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom

# %%
# Feature Engineering
del data2['InvoiceNo']
del data2['StockCode']
del data2['Description']
del data2['Country']
del data2['InvoiceDate']

# %%
data2.head()
# Out:
#    Quantity  UnitPrice CustomerID
# 0         6       2.55    17850.0
# 1         6       3.39    17850.0
# 2         8       2.75    17850.0
# 3         6       3.39    17850.0
# 4         6       3.39    17850.0

# %%
aggregation_functions = {
    'Quantity': 'sum',
    'UnitPrice': 'first',
   
}

# %%
## extra data duplicates were created in order to prevent the orginal data just in case if data operations go south.And easy acess the main whenever required

# %%
#Creating a new data frame purely to check induvidual quantity
data3 = data2.groupby('CustomerID', as_index=False).agg(aggregation_functions)

# %%
##These are the Top 20 Customers for the E-commerce store
## Giving them special intrests and discounts ,fast delivery will retain these customers.
data3.head(20)
# Out:
#    CustomerID  Quantity  UnitPrice
# 0     12346.0         0       1.04
# 1     12347.0      2458       2.10
# 2     12348.0      2341       0.55
# 3     12349.0       631       7.50
# 4     12350.0       197       2.10
# 5     12352.0       470       2.95
# 6     12353.0        20       9.95
# 7     12354.0       530       2.08
# 8     12355.0       240       1.25
# 9     12356.0      1591       4.25
# 10    12357.0      2708       1.65
# 11    12358.0       248       3.75
# 12    12359.0      1612       1.25
# 13    12360.0      1165       0.85
# 14    12361.0        91       1.95
# 15    12362.0      2212       3.75
# 16    12363.0       408       7.95
# 17    12364.0      1506      15.00
# 18    12365.0       173       1.25
# 19    12367.0       173       0.85

# %%
## Further QoQ and Revenue share by each country is neatly shown in Tableau Desktop.
https://public.tableau.com/app/profile/vamsikrishna.surisetti/viz/Dashboardofaglobalretailstore/Dashboard1
Click on above link to see in detail EDA and visualisations.
